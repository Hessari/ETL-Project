# %% [markdown]
# # #Import dependencies#

# %%
import pandas as pd
import os 
from sqlalchemy import create_engine

# %% [markdown]
# # Extract CSV & Excel files into DataFrames

# %%
population_path= r"C:\Users\Zaid Al-Saffar\Desktop\ETL Project\Population.csv"
MedianListingPrice_path= r"C:\Users\Zaid Al-Saffar\Desktop\ETL Project\City_MedianListingPrice_AllHomes.xlsx"
Regaion_path= r"C:\Users\Zaid Al-Saffar\Desktop\ETL Project\California Welfare Directors Association (CWDA).xlsx"

# %%
population_df=pd.read_csv(population_path)

population_df.head(3)
# Out:
#    fips   county  year  age  pop_female  pop_male  pop_total
# 0  6001  ALAMEDA  2017    0        9343     10293      19636
# 1  6001  ALAMEDA  2017    1        9388     10080      19468
# 2  6001  ALAMEDA  2017    2        9434     10004      19438

# %%
MedianListingPrice_df= pd.read_excel(MedianListingPrice_path)
MedianListingPrice_df

#MedianListingPrice_df['CountyName']=MedianListingPrice_df['CountyName'].str.upper().str.replace(" COUNTY", "")
#MedianListingPrice_df
# Out:
#      fips        RegionName State                                Metro  \
# 0    6001           Oakland    CA        San Francisco-Oakland-Hayward
# 1    6001           Fremont    CA        San Francisco-Oakland-Hayward
# 2    6001           Hayward    CA        San Francisco-Oakland-Hayward
# 3    6001          Berkeley    CA        San Francisco-Oakland-Hayward
# 4    6001       San Leandro    CA        San Francisco-Oakland-Hayward
# 5    6001         Livermore    CA        San Francisco-Oakland-Hayward
# 6    6001        Pleasanton    CA        San Francisco-Oakland-Hayward
# 7    6001        Union City    CA        San Francisco-Oakland-Hayward
# 8    6001           Alameda    CA        San Francisco-Oakland-Hayward
# 9    6001     Castro Valley    CA        San Francisco-Oakland-Hayward
# 10   6001            Dublin    CA        San Francisco-Oakland-Hayward
# 11   6001            Newark    CA        San Francisco-Oakland-Hayward
# ...

# %%
Regaion_df= pd.read_excel(Regaion_path)

Regaion_df.head(29)
# Out:
#     Region Id                  Region_Name  Fips      County_Name
# 0           3  Mother Lode Mountain Region  6005           Amador
# 1           3  Mother Lode Mountain Region  6009        Calaveras
# 2           2               Coastal Region  6013     Contra Costa
# 3           1               Northen Region  6015        Del Norte
# 4           3  Mother Lode Mountain Region  6017        El Dorado
# 5           1               Northen Region  6021            Glenn
# 6           1               Northen Region  6023         Humboldt
# 7           3  Mother Lode Mountain Region  6027             Inyo
# 8           4               Central Region  6029             Kern
# 9           4               Central Region  6031            Kings
# 10          1               Northen Region  6033             Lake
# 11          5              Southern Region  6037      Los Angeles
# 12          4               Central Region  6039           Madera
# ...

# %%
#.drop_duplicates(inplace=True)

# %%
#county_id = pd.DataFrame(county_id).reset_index(drop=True)

# %% [markdown]
# # Create database connection

# %%
rds_connecting_string= "root:root@127.0.0.1:3306/ca_population"
engine= create_engine('mysql+pymysql://{}'.format(rds_connecting_string))

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@127.0.0.1:3306/ca_population)

# %%
population_df.to_sql(name='population', con=engine, if_exists='append', index=True)

# %%
MedianListingPrice_df.to_sql(name='home_price', con=engine, if_exists="append", index=True)

# %%
Regaion_df.to_sql(name='regain', con=engine, if_exists="append", index=True)
